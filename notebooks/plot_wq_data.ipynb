# %%
# Import libraries
import os
import glob

import seaborn as sns; sns.set_theme()
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# Input arguments
wd = 'D:/'

# %%
# Change working directory
os.chdir(wd)

# %%
# Directory for figures
fig_dir = 'est_water_qual/data/kese/figures'

# %%
# Parameters
params = ['tn', 'tp']

# %%
# Create monthly histogram plot
images = glob.glob(f'{fig_dir}/*_obs_monthly_hist.png')
fig, axes = plt.subplots(1, 2, figsize=(8, 6))
for image, ax in zip(images, axes.flatten()):
    img = mpimg.imread(image)
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.savefig(f'{fig_dir}/obs_monthly_hist.png', dpi=300, bbox_inches='tight')

# %%
# Create monthly heatmap plot
images = glob.glob(f'{fig_dir}/*_obs_monthly_heat.png')
fig, axes = plt.subplots(1, 2, figsize=(8, 6))
for image, ax in zip(images, axes.flatten()):
    img = mpimg.imread(image)
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.savefig(f'{fig_dir}/obs_monthly_heat.png', dpi=300, bbox_inches='tight')

# %%
# Create yearly histogram plot
images = glob.glob(f'{fig_dir}/*_obs_yearly_hist.png')
fig, axes = plt.subplots(1, 2, figsize=(8, 6))
for image, ax in zip(images, axes.flatten()):
    img = mpimg.imread(image)
    ax.imshow(img)
    ax.axis('off')
plt.tight_layout()
plt.savefig(f'{fig_dir}/obs_yearly_hist.png', dpi=300, bbox_inches='tight')
